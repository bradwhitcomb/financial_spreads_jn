# %%
from spread_template import excel_to_dataframe

# %%
_, pl_df, bs_df, cf_df = excel_to_dataframe('SimFin-aapl_qe318.xlsx')

# %%
bs_df
# Out:
# 16                                                  Q4 '14  Q1 '15  Q2 '15  \
# in million USD
# Assets                                                 NaN     NaN     NaN
# Cash and cash equivalents                            13844   19478   14489
# Short-term marketable securities                     11233   12985   18607
# Accounts receivable, less allowances of $82 and...   17460   16709   10905
# Inventories                                           2111    2283    2396
# Deferred tax assets                                   4318    5046    5141
# Vendor non-trade receivables                          9759   13267    7259
# Other current assets                                  9806   13635    9094
# Total current assets                                 68531   83403   67891
# Long-term marketable securities                     130162  145492  160443
# Property, plant and equipment, net                   20624   20392   20151
# ...

# %%
bs_df.loc["Do TA and TLE Foot"] = bs_df.loc['Total assets'] == bs_df.loc["Total liabilities and shareholders' equity"]
bs_df.loc['Do Assets Foot'] = bs_df.loc['Total assets'] == bs_df.loc['Cash and cash equivalents']+ bs_df.loc['Short-term marketable securities'] + bs_df.loc['Accounts receivable, less allowances of $82 and $86, respectively']+bs_df.loc['Inventories']+bs_df.loc['Deferred tax assets']+bs_df.loc['Vendor non-trade receivables']+bs_df.loc['Other current assets']+bs_df.loc['Long-term marketable securities']+bs_df.loc['Property, plant and equipment, net']+bs_df.loc['Goodwill']+bs_df.loc['Acquired intangible assets, net']+bs_df.loc['Other assets']

# %%
bs_df
bs_df.drop(bs_df.loc['Assets'])
# Out:
# 16                                                  Q4 '14  Q1 '15  Q2 '15  \
# in million USD
# Assets                                                 NaN     NaN     NaN
# Cash and cash equivalents                            13844   19478   14489
# Short-term marketable securities                     11233   12985   18607
# Accounts receivable, less allowances of $82 and...   17460   16709   10905
# Inventories                                           2111    2283    2396
# Deferred tax assets                                   4318    5046    5141
# Vendor non-trade receivables                          9759   13267    7259
# Other current assets                                  9806   13635    9094
# Total current assets                                 68531   83403   67891
# Long-term marketable securities                     130162  145492  160443
# Property, plant and equipment, net                   20624   20392   20151
# ...

# %%
bs_df.T[['Total assets', 'Total liabilities', "Total shareholders' equity" ]].plot()
